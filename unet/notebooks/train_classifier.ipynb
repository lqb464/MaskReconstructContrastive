# %%
# !git clone https://github.com/HoangVo-Prog/MaskReconstructContrastive.git
# !git clone https://github.com/ddlinh/vista.git
# Out:
# Cloning into 'MaskReconstructContrastive'...
# remote: Enumerating objects: 973, done.
# remote: Counting objects: 100% (270/270), done.
# remote: Compressing objects: 100% (218/218), done.
# remote: Total 973 (delta 86), reused 223 (delta 40), pack-reused 703 (from 2)
# Receiving objects: 100% (973/973), 594.87 MiB | 45.58 MiB/s, done.
# Resolving deltas: 100% (375/375), done.
# Updating files: 100% (154/154), done.
# Cloning into 'vista'...
# remote: Enumerating objects: 274, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 274 (delta 19), reused 29 (delta 10), pack-reused 235 (from 2)
# Receiving objects: 100% (274/274), 113.11 MiB | 33.28 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# Updating files: 100% (210/210), done.

# %%
# %cd MaskReconstructContrastive
# !git pull
# %cd ..
# Out:
# /kaggle/working/MaskReconstructContrastive
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 6 (delta 5), reused 6 (delta 5), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 497 bytes | 248.00 KiB/s, done.
# From https://github.com/HoangVo-Prog/MaskReconstructContrastive
#    c54d2d7..04d009b  main       -> origin/main
# Updating c54d2d7..04d009b
# Fast-forward
#  unet/src/v4/train_bottleneck_classifier.py | 3 +--
#  1 file changed, 1 insertion(+), 2 deletions(-)
# /kaggle/working

# %%
# !python MaskReconstructContrastive/unet/src/v4/train_bottleneck_classifier.py \
    --csv-path /kaggle/working/vista/data/data_description.csv \
    --images-root /kaggle/working/vista/data/images \
    --ckpt-path /kaggle/input/unet-20m-mixed/pytorch/default/1/ckpt_best.pt \
    --batch-size 8 \
    --epochs 100 \
    --device cuda
# Out:
# Epoch 001 | Train loss 1.3229 acc 0.5104 | Val loss 1.1934 acc 0.4583
# Label counts: tensor([ 4, 11,  8,  1])
# Pred counts: tensor([ 0, 24,  0,  0])
# Confusion matrix (rows=true, cols=pred):
# tensor([[ 0,  4,  0,  0],
#         [ 0, 11,  0,  0],
#         [ 0,  8,  0,  0],
#         [ 0,  1,  0,  0]])
# Epoch 002 | Train loss 1.2738 acc 0.4583 | Val loss 1.1706 acc 0.4583
# Label counts: tensor([ 4, 11,  8,  1])
# Pred counts: tensor([ 0, 24,  0,  0])
# Confusion matrix (rows=true, cols=pred):
# tensor([[ 0,  4,  0,  0],
#         [ 0, 11,  0,  0],
#         [ 0,  8,  0,  0],
#         [ 0,  1,  0,  0]])
# Epoch 003 | Train loss 1.2489 acc 0.4479 | Val loss 1.1491 acc 0.4583
# Label counts: tensor([ 4, 11,  8,  1])
# Pred counts: tensor([ 0, 24,  0,  0])
# Confusion matrix (rows=true, cols=pred):
# tensor([[ 0,  4,  0,  0],
#         [ 0, 11,  0,  0],
#         [ 0,  8,  0,  0],
#         [ 0,  1,  0,  0]])
# Epoch 004 | Train loss 1.2243 acc 0.4583 | Val loss 1.1288 acc 0.4583
# ...
