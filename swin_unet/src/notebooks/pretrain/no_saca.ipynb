# %% [markdown]
# # Pretrain Without SACA
#
# Edit the placeholder paths and run the CLI command below.

# %%
# !python -m swin_unet.src.cli train-ssl --data-root /path/to/pretrain/data --image-size 192 --batch-size 64 --epochs 200 --lambda-recon 1.0 --lambda-contrast 1.0 --out-dir runs --run-name pretrain_no_saca
