# %% [markdown]
# # Skull Stripping With Multi SACA
#
# Edit the placeholder paths and run the CLI command below.

# %%
# !python -m swin_unet.src.cli train-skull --train_dir /path/to/skull_stripping/train --val_dir /path/to/skull_stripping/val --image-size 256 --batch-size 16 --epochs 50 --disable-contrastive --disable-masking --enable_saca --saca_positions after_patch_embed,after_stage0,after_stage1 --out-dir runs --run-name skull_stripping_multi_saca
