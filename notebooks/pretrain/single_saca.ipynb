# %% [markdown]
# # Pretrain With Single SACA
#
# Edit the placeholder paths and run the CLI command below.

# %%
# !python -m swin_unet.src.ver4.cli train-ssl --data-root /path/to/pretrain/data --image-size 192 --batch-size 64 --epochs 200 --lambda-recon 1.0 --lambda-contrast 1.0 --enable_saca --saca_position after_stage1 --out-dir runs_ver4 --run-name pretrain_single_saca
