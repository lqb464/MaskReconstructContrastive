# %% [markdown]
# # Skull Stripping Without SACA
#
# Edit the placeholder paths and run the CLI command below.

# %%
# !python -m swin_unet.src.ver4.cli train-skull --train_dir /path/to/skull_stripping/train --val_dir /path/to/skull_stripping/val --image-size 256 --batch-size 16 --epochs 50 --disable-contrastive --disable-masking --out-dir runs_ver4 --run-name skull_stripping_no_saca
