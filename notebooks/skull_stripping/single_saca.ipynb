# %% [markdown]
# # Skull Stripping With Single SACA
#
# Edit the placeholder paths and run the CLI command below.

# %%
# !python -m swin_unet.src.ver4.cli train-skull --train_dir /path/to/skull_stripping/train --val_dir /path/to/skull_stripping/val --image-size 256 --batch-size 16 --epochs 50 --disable-contrastive --disable-masking --enable_saca --saca_position after_stage1 --out-dir runs_ver4 --run-name skull_stripping_single_saca
